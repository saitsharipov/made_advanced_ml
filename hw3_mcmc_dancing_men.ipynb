# %% [markdown]
# # $\color{blue}{\text{MADE}}$ $\bullet$ $\color{red}{\text{Advanced ML}}$ $\bullet$ HW №3
# ### Преподаватель: [*Сергей Николенко*](https://logic.pdmi.ras.ru/~sergey/index.html)
# ### Выполнил: $\text{Саит Шарипов, группа MADE-DS-22}$
# ### 🕺 👯 💃 MCMC-сэмплирование и «пляшущие человечки».
# * * *

# %% [markdown]
# # 📝 [Описание задания](https://docs.google.com/document/d/1FWCuz-3Q_85yQYEwz6xVkIuXUjQn60dVFxreJId-liM/edit):

# %% [markdown]
# Третье домашнее задание посвящено достаточно простой, но, надеюсь, интересной задаче, в которой потребуется творчески применить методы сэмплирования. Как и раньше, в качестве решения ожидается ссылка на `jupyter-ноутбук` на вашем `github` (или публичный, или с доступом для *snikolenko*); ссылку обязательно нужно прислать в виде сданного домашнего задания на портале Академии. Как всегда, любые комментарии, новые идеи и рассуждения на тему категорически приветствуются.
#
# В этом небольшом домашнем задании мы попробуем улучшить метод Шерлока Холмса. Как известно, в рассказе *The Adventure of the Dancing Men* великий сыщик расшифровал загадочные письмена, которые выглядели примерно так:

# %% [markdown]
# ![dancing_men.png](attachment:dancing_men.png)

# %% [markdown]
# Пользовался он для этого так называемым частотным методом: смотрел, какие буквы чаще встречаются в зашифрованных текстах, и пытался подставить буквы в соответствии с частотной таблицей: E — самая частая и так далее.
#
# В этом задании мы будем разрабатывать более современный и продвинутый вариант такого частотного метода. В качестве корпусов текстов для подсчётов частот можете взять что угодно, но для удобства вот вам *“Война и мир”* по-русски и по-английски: [ссылка](https://www.dropbox.com/s/k23enjvr3fb40o5/corpora.zip)

# %% [markdown]
# 1. Реализуйте базовый частотный метод по Шерлоку Холмсу:
#     * подсчитайте частоты букв по корпусам (пунктуацию и капитализацию можно просто опустить, а вот пробелы лучше оставить);
#     * возьмите какие-нибудь тестовые тексты (нужно взять по меньшей мере $2$-$3$ предложения, иначе вряд ли сработает), зашифруйте их посредством случайной перестановки символов;
#     * расшифруйте их таким частотным методом.
#
#
# 2. Вряд ли в результате получилась такая уж хорошая расшифровка, разве что если вы брали в качестве тестовых данных целые рассказы. Но и Шерлок Холмс был не так уж прост: после буквы E, которая действительно выделяется частотой, дальше он анализировал уже конкретные слова и пытался угадать, какими они могли бы быть. Я не знаю, как запрограммировать такой интуитивный анализ, так что давайте просто сделаем следующий логический шаг:
#     * подсчитайте частоты биграмм (т.е. пар последовательных букв) по корпусам;
#     * проведите тестирование аналогично п.1, но при помощи биграмм$^1$.
#
#
# 3. Но и это ещё не всё: биграммы скорее всего тоже далеко не всегда работают. Основная часть задания — в том, как можно их улучшить:
#     * предложите метод обучения перестановки символов в этом задании, основанный на MCMC-сэмплировании, но по-прежнему работающий на основе статистики биграмм;
#     * реализуйте и протестируйте его, убедитесь, что результаты улучшились.
#
#
# 4. Расшифруйте сообщение:
# ←⇠⇒↟↹↷⇊↹↷↟↤↟↨←↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↟⇒↟↹⇷⇛⇞↨↟↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↨←⇌⇠↨↹⇙↹⇸↨⇛↙⇛↹⇠⇛⇛↲⇆←↝↟↞↹⇌⇛↨⇛⇯⇊↾↹⇒←↙⇌⇛↹⇷⇯⇛⇞↟↨⇴↨⇈↹ ⇠⇌⇛⇯←←↹↷⇠←↙⇛↹↷⇊↹↷⇠←↹⇠↤←⇒⇴⇒↟↹⇷⇯⇴↷↟⇒⇈↝⇛↹↟↹⇷ ⇛⇒⇙⇞↟↨←↹↳⇴⇌⇠↟↳⇴⇒⇈↝⇊↾↹↲⇴⇒⇒↹⇰⇴↹⇷⇛⇠⇒←↤↝←←↹⇞←↨↷←⇯↨⇛←↹⇰⇴↤⇴
# ↝↟←↹⇌⇙⇯⇠⇴↹↘⇛↨↞↹⇌⇛↝←⇞↝⇛↹↞↹↝↟⇞←↙⇛↹↝←↹⇛↲←⇆⇴⇏
#
#     Или это (они одинаковые, второй вариант просто на случай проблем с юникодом):
#
#     დჳჵჂႨშႼႨშჂხჂჲდႨსႹႭჾႣჵისႼჰႨჂჵჂႨႲႹႧჲჂႨსႹႭჾႣჵისႼჰႨჲდႩჳჲႨჇႨႠჲႹქႹႨჳႹႹჱჶდსჂႽႨႩႹჲႹႭႼჰႨჵდქႩႹႨႲႭႹႧჂჲႣჲიႨჳႩ
#     ႹႭდდႨშჳდქႹႨშႼႨშჳდႨჳხდჵႣჵჂႨႲႭႣშჂჵისႹႨჂႨႲႹჵჇႧჂჲდႨჾႣႩჳჂჾႣჵისႼჰႨჱႣჵჵႨეႣႨႲႹჳჵდხსდდႨႧდჲშდႭჲႹდႨეႣხႣსჂდ
#     ႨႩჇႭჳႣႨႾႹჲႽႨႩႹსდႧსႹႨႽႨსჂႧდქႹႨსდႨႹჱდჶႣნ
#
#
# 5. 🎁 *Бонус:* а что если от биграмм перейти к триграммам (тройкам букв) или даже больше? Улучшатся ли результаты? Когда улучшатся, а когда нет? Чтобы ответить на этот вопрос эмпирически, уже может понадобиться погенерировать много тестовых перестановок и последить за метриками, глазами может быть и не видно.
#
#
# 6. 🎁 *Бонус:* какие вы можете придумать применения для этой модели? Пляшущие человечки ведь не так часто встречаются в жизни (хотя встречаются! и это самое потрясающее во всей этой истории, но об этом я расскажу потом).
#
# ---
# $^1$В качестве естественной метрики качества можно взять долю правильно расшифрованных букв или, если хочется совсем математически изощриться, расстояние между двумя перестановками, правильной и полученной из модели; но, честно говоря, в этом задании следить за численными метриками не так уж обязательно, будет и глазами всё видно.

# %% [markdown]
# # ✅ Решение

# %% [markdown]
# ## 0️⃣ Импорт библиотек

# %%
import re
from collections import Counter

import random
random.seed(1234)

import copy

import numpy as np

# Русский алфавит с пробелом, но без буквы ё.
RUSSIAN_ALPHABET_SPACE = "абвгдежзийклмнопрстуфхцчшщъыьэюя "


# --- Для визуализации --- 
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette("colorblind")
palette = sns.color_palette()

plt.style.use(['science','ieee','no-latex']) # для формул в графиках
plt.rc('font',**{'family':'sans-serif'}) # шрифт
plt.rc('figure', **{'dpi': 1000}) # качество графиков


figsize = (15, 8)
legend_fontsize = 19
axis_fontsize = 16
# --- ------------- ---

# %% [markdown]
# ## 1️⃣ Базовый частотный метод по Шерлоку Холмсу
#
# Реализуйте базовый частотный метод по Шерлоку Холмсу:
# * подсчитайте частоты букв по корпусам (пунктуацию и капитализацию можно просто опустить, а вот пробелы лучше оставить);
# * возьмите какие-нибудь тестовые тексты (нужно взять по меньшей мере $2$-$3$ предложения, иначе вряд ли сработает), зашифруйте их посредством случайной перестановки символов;
# * расшифруйте их таким частотным методом.

# %%
# Читаем "Войну и мир" по-русски.
with open("data/WarAndPeaceRus.txt", "r", encoding="utf-8") as fin:
    corpus_rus_lines = fin.readlines()
    
# Конкантенируем все строки в единую строку.
corpus_rus = ''.join(corpus_rus_lines)

# %%
def preprocess_rus_text(text: str) -> str:
    """Предобработка русского текста."""
    # Капитализацию можно просто опустить.
    text = text.lower()
    # Удалим все символы кроме букв и пробела.
    text = re.sub("[^а-я ]", " ", text)
    # Удаление двойных пробелов.
    text = re.sub(' +',' ', text).strip()
    return text

# %%
print(f"Всего символов в русской версии было до предобработки: {len(corpus_rus)}")
corpus_rus = preprocess_rus_text(corpus_rus)
print(f"Всего символов в русской версии стало после предобработки: {len(corpus_rus)}")
# Out:
# Всего символов в русской версии было до предобработки: 717873
# Всего символов в русской версии стало после предобработки: 643122

# %%
# Cчитаем частоты букв по корпусу.
frequencies_dict = dict(Counter(corpus_rus))

# %%
# Строим график частот букв.

frequencies_list_rus = []
for symbol in RUSSIAN_ALPHABET_SPACE:
    frequencies_list_rus.append(frequencies_dict[symbol])
        
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=figsize)

ax.bar(list(RUSSIAN_ALPHABET_SPACE), frequencies_list_rus, color='dodgerblue')
ax.set_title(r'Частоты символов в "Войне и мире"', fontsize=legend_fontsize)
ax.set_xlabel(r'Символы', fontsize=axis_fontsize)
ax.set_ylabel(r'Частота символов', fontsize=axis_fontsize)

plt.show()

# %%
# Шифр на основе случайной перестановки символов алфавита.
SHUFFLE_RUSSIAN_ALPHABET_SPACE = list(RUSSIAN_ALPHABET_SPACE)
random.shuffle(SHUFFLE_RUSSIAN_ALPHABET_SPACE)
SHUFFLE_RUSSIAN_ALPHABET_SPACE = "".join(SHUFFLE_RUSSIAN_ALPHABET_SPACE)

print("Оригинальный русский алфавит: {}".format(RUSSIAN_ALPHABET_SPACE))
print("Шифр русского алфавита: {}".format(SHUFFLE_RUSSIAN_ALPHABET_SPACE))
# Out:
# Оригинальный русский алфавит: абвгдежзийклмнопрстуфхцчшщъыьэюя
# Шифр русского алфавита: жкешдионсрмъчфйп ыуюялгэцхбтщвазь

# %%
# Получаем словарь для кодирования.
dict_translation = str.maketrans(RUSSIAN_ALPHABET_SPACE, SHUFFLE_RUSSIAN_ALPHABET_SPACE)

# %%
def encode_text(text: str, dict_translation: dict) -> str:
    """Кодирование текста на основе перестановки символов алфавита."""
    return text.translate(dict_translation)

# %%
def decode_text(text: str, frequencies_dict: dict) -> str:
    """Декодирование текста на основе частотного метода по Шерлоку Холмсу."""
    
    sorted_frequencies_corpus = sorted(list(frequencies_dict.items()), key=lambda x: x[1], reverse=True)
    frequencies_alphabet1 = "".join([x[0] for x in sorted_frequencies_corpus])
    
    frequencies_dict2 = dict(Counter(text))
    sorted_frequencies_corpus2 = sorted(list(frequencies_dict2.items()), key=lambda x: x[1], reverse=True)
    frequencies_alphabet2 = "".join([x[0] for x in sorted_frequencies_corpus2])
    
    dict_translation = str.maketrans(frequencies_alphabet2, frequencies_alphabet1)
    return text.translate(dict_translation)

# %%
def get_accuracy_decode(source_text: str, decode_text: str) -> float:
    hit = 0
    for x1, x2 in zip(source_text, decode_text):
        if x1 == x2:
            hit += 1
    return hit / len(source_text)

# %% [markdown]
# <font color='Navy'><i>
# ✏️ В качестве примера текста, который будем шифровать, возьмем начало "Анны Карениной".
# </i></font>

# %%
# Читаем "Анну Каренину" по-русски.
with open("data/AnnaKareninaRus.txt", "r", encoding="utf-8") as fin:
    anna_rus_lines = fin.readlines()
    
# Конкантенируем все строки в единую строку.
anna_rus_text = ''.join(anna_rus_lines)
# Предобработка текста.
anna_rus_text = preprocess_rus_text(anna_rus_text)

EXAMPLE_TEXT_ANNA = anna_rus_text[32793:34793]

# %%
EXAMPLE_TEXT_ANNA = anna_rus_text[32793:34793]
print("📖 Для тестирования взят отрывок из {} символов из Анны Карениной.\n".format(len(EXAMPLE_TEXT_ANNA)))

print("📍 Исходный текст:\n{}".format(EXAMPLE_TEXT_ANNA[:250]))
cipher_text = encode_text(EXAMPLE_TEXT_ANNA, dict_translation)
print("\n🔒 Зашифрованный текст:\n{}".format(cipher_text[:250]))
decode_cipher_text = decode_text(cipher_text, frequencies_dict)
print("\n🔐 Дешифрованный текст:\n{}".format(decode_cipher_text[:250]))

print("\n📈 Accuracy декодирования: {}".format(get_accuracy_decode(EXAMPLE_TEXT_ANNA, decode_cipher_text)))
# Out:
# 📖 Для тестирования взят отрывок из 2000 символов из Анны Карениной.
#
# 📍 Исходный текст:
# все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему все смешалось в доме облонских жена узнала что муж был в связи с бывшею в их доме француженкою гувернанткой и объявила мужу что не может жить с ним в одном доме
#
# 🔒 Зашифрованный текст:
# еыиьыэжыуъсетиьыичщсьпйлйосьд юшьфжьд юшжьмжоджзьфиыэжыуъсежзьыичщзьфиыэжыуъсежьпйьыейичюьеыиьычицжъйыщьеьдйчиьйкъйфымсльоифжьюнфжъжьэуйьчюоьктъьеьыезнсьыьктециаьеьсльдйчиья жфгюоифмйаьшюеи фжфумйрьсьйкбзесъжьчюоюьэуйьфиьчйоиуьосущьыьфсчьеьйдфйчьдйчи
#
# 🔐 Дешифрованный текст:
# вте тяатлснвге текьн похобн рдуч иа рдуча мабраы иетяатлснваы текьы иетяатлснва по твоеку вте ткежасоть в роке озсоитмнх беиа ушиаса яло куб згс в твышн т згвжею в нх роке цдаиэубеимою чуведиаилмой н озъывнса кубу яло ие кобел бнль т инк в ориок роке
#
# 📈 Accuracy декодирования: 0.52

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Видим, что на отрыке из $2000$ символов можно что-то разобрать (имея перед глазами исходный текст), но с трудом, честно говоря. Давайте посмотрим, на качество дешифрования при большем объеме тестового текста из Анны Карениной для дешифровки.
# </i></font>

# %%
EXAMPLE_TEXT_ANNA = anna_rus_text[32793:52793]
print("📖 Для тестирования взят отрывок из {} символов из Анны Карениной.\n".format(len(EXAMPLE_TEXT_ANNA)))

print("📍 Исходный текст:\n{}".format(EXAMPLE_TEXT_ANNA[:250]))
cipher_text = encode_text(EXAMPLE_TEXT_ANNA, dict_translation)
print("\n🔒 Зашифрованный текст:\n{}".format(cipher_text[:250]))
decode_cipher_text = decode_text(cipher_text, frequencies_dict)
print("\n🔐 Дешифрованный текст:\n{}".format(decode_cipher_text[:250]))

print("\n📈 Accuracy декодирования: {}".format(get_accuracy_decode(EXAMPLE_TEXT_ANNA, decode_cipher_text)))
# Out:
# 📖 Для тестирования взят отрывок из 20000 символов из Анны Карениной.
#
# 📍 Исходный текст:
# все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему все смешалось в доме облонских жена узнала что муж был в связи с бывшею в их доме француженкою гувернанткой и объявила мужу что не может жить с ним в одном доме
#
# 🔒 Зашифрованный текст:
# еыиьыэжыуъсетиьыичщсьпйлйосьд юшьфжьд юшжьмжоджзьфиыэжыуъсежзьыичщзьфиыэжыуъсежьпйьыейичюьеыиьычицжъйыщьеьдйчиьйкъйфымсльоифжьюнфжъжьэуйьчюоьктъьеьыезнсьыьктециаьеьсльдйчиья жфгюоифмйаьшюеи фжфумйрьсьйкбзесъжьчюоюьэуйьфиьчйоиуьосущьыьфсчьеьйдфйчьдйчи
#
# 🔐 Дешифрованный текст:
# все сьастливбе семяи поюойи друы на друыа кайдаг несьастливаг семяг несьастлива по своему все смешалося в доме озлонскию йена учнала ьто муй збл в свгчи с збвшех в ию доме франэуйенкох ыувернанткож и озъгвила муйу ьто не мойет йитя с ним в одном доме
#
# 📈 Accuracy декодирования: 0.8561

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Видим, что на отрыке из $20000$ символов можно разобрать почти все, да и Accuracy увеличилась.
# </i></font>

# %% [markdown]
# ## 2️⃣ Частотный подход на основе биграмм
# Вряд ли в результате получилась такая уж хорошая расшифровка, разве что если вы брали в качестве тестовых данных целые рассказы. Но и Шерлок Холмс был не так уж прост: после буквы E, которая действительно выделяется частотой, дальше он анализировал уже конкретные слова и пытался угадать, какими они могли бы быть. Я не знаю, как запрограммировать такой интуитивный анализ, так что давайте просто сделаем следующий логический шаг:
# * подсчитайте частоты биграмм (т.е. пар последовательных букв) по корпусам;
# * проведите тестирование аналогично п.1, но при помощи биграмм.

# %%
def get_frequencies_bigram_dict(text: str):
    frequencies_bigram_dict = Counter([text[i:i+2] for i in range(len(text) - 1)])
    
    # Для сглаживания и чтобы словари частот были одной длины у разных текстов.
    for c1 in RUSSIAN_ALPHABET_SPACE:
        for c2 in RUSSIAN_ALPHABET_SPACE:
            frequencies_bigram_dict[c1 + c2] += 1
            
    return dict(frequencies_bigram_dict)

# %%
frequencies_bigram_dict = get_frequencies_bigram_dict(corpus_rus)

# %%
def bigram_decode_text(text: str, frequencies_bigram_dict: dict) -> str:
    """Декодирование текста на основе частот биграм."""
    
    sorted_frequencies_corpus = sorted(list(frequencies_bigram_dict.items()), key=lambda x: x[1], reverse=True)
    frequencies_bigram1 = [x[0] for x in sorted_frequencies_corpus]
    
    frequencies_bigram_dict2 = get_frequencies_bigram_dict(text)
    sorted_frequencies_corpus2 = sorted(list(frequencies_bigram_dict2.items()), key=lambda x: x[1], reverse=True)
    frequencies_bigram2 = [x[0] for x in sorted_frequencies_corpus2]
    
    dict_translation = {}
    for bigram1, bigram2 in zip(frequencies_bigram1, frequencies_bigram2):
        dict_translation[bigram2] = bigram1
    
    decode_text_output = []
    
    for i in range(0, len(text) - 1, 2):
        decode_text_output.append(dict_translation[text[i:i+2]])
    return "".join(decode_text_output)

# %%
EXAMPLE_TEXT_ANNA = anna_rus_text[32793:52793]
print("📖 Для тестирования взят отрывок из {} символов из Анны Карениной.\n".format(len(EXAMPLE_TEXT_ANNA)))

print("📍 Исходный текст:\n{}".format(EXAMPLE_TEXT_ANNA[:250]))
cipher_text = encode_text(EXAMPLE_TEXT_ANNA, dict_translation)
print("\n🔒 Зашифрованный текст:\n{}".format(cipher_text[:250]))
decode_cipher_text = bigram_decode_text(cipher_text, frequencies_bigram_dict)
print("\n🔐 Дешифрованный текст:\n{}".format(decode_cipher_text[:250]))

print("\n📈 Accuracy декодирования: {}".format(get_accuracy_decode(EXAMPLE_TEXT_ANNA, decode_cipher_text)))
# Out:
# 📖 Для тестирования взят отрывок из 20000 символов из Анны Карениной.
#
# 📍 Исходный текст:
# все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему все смешалось в доме облонских жена узнала что муж был в связи с бывшею в их доме француженкою гувернанткой и объявила мужу что не может жить с ним в одном доме
#
# 🔒 Зашифрованный текст:
# еыиьыэжыуъсетиьыичщсьпйлйосьд юшьфжьд юшжьмжоджзьфиыэжыуъсежзьыичщзьфиыэжыуъсежьпйьыейичюьеыиьычицжъйыщьеьдйчиьйкъйфымсльоифжьюнфжъжьэуйьчюоьктъьеьыезнсьыьктециаьеьсльдйчиья жфгюоифмйаьшюеи фжфумйрьсьйкбзесъжьчюоюьэуйьфиьчйоиуьосущьыьфсчьеьйдфйчьдйчи
#
# 🔐 Дешифрованный текст:
# лье ушинибесха сх бо нзстуа ыйце пи ыйцеи гозвсе пчтпея ил чь одишь ноушинибеси ов серх оллье двпиаллистреогим врнра е шсьони вп иоснитоелдуу му о сжуиг су тсшедере шна ме уеомюбтанчах уошск иур т ба рузбисоселдуолт о ноелтуатсьлест алоенреавпоеногим
#
# 📈 Accuracy декодирования: 0.1803

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Видим, что на отрыке из $20000$ символов биграммы работают плохо. Неудивительно, так как для того, чтобы уловитть частотность биграмм потребуется намного больший корпус.
# </i></font>

# %%
EXAMPLE_TEXT_ANNA = anna_rus_text
print("📖 Для тестирования взят отрывок из {} символов из Анны Карениной.\n".format(len(EXAMPLE_TEXT_ANNA)))

print("📍 Исходный текст:\n{}".format(EXAMPLE_TEXT_ANNA[:250]))
cipher_text = encode_text(EXAMPLE_TEXT_ANNA, dict_translation)
print("\n🔒 Зашифрованный текст:\n{}".format(cipher_text[:250]))
decode_cipher_text = bigram_decode_text(cipher_text, frequencies_bigram_dict)
print("\n🔐 Дешифрованный текст:\n{}".format(decode_cipher_text[:250]))

print("\n📈 Accuracy декодирования: {}".format(get_accuracy_decode(EXAMPLE_TEXT_ANNA, decode_cipher_text)))
# Out:
# 📖 Для тестирования взят отрывок из 1694973 символов из Анны Карениной.
#
# 📍 Исходный текст:
# анна каренина один из самых знаменитых романов льва толстого начинается ставшей афоризмом фразой все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему это книга о вечных ценностях о любви о вере о семье о человечес
#
# 🔒 Зашифрованный текст:
# жффжьмж ифсфжьйдсфьсньыжчтльнфжчифсутль йчжфйеьъщежьуйъыуйшйьфжэсфжиуызьыужецирьжяй снчйчья жнйрьеыиьыэжыуъсетиьыичщсьпйлйосьд юшьфжьд юшжьмжоджзьфиыэжыуъсежзьыичщзьфиыэжыуъсежьпйьыейичюьвуйьмфсшжьйьеиэфтльгиффйыузльйьъакесьйьеи иьйьыичщиьйьэиъйеиэиы
#
# 🔐 Дешифрованный текст:
# ат инехо тлеа азле к хспумаяудсл тмиечетоматм есчла  нр  нно слюлезьагя струмувотл мсвинрорвемх  вак пбосттакни акппе коэтул былпи и быльенеичдая натяю ргмеей пбыиг смобосттапртоо идивма а ннел ье о вашвсаяоючелинтаяо цедме о вери о пбыыт оу орм ашмо
#
# 📈 Accuracy декодирования: 0.25290963336879113

# %% [markdown]
# <font color='Navy'><i>
# ✏️ На всем тексте точность выросла, но все равно распределение слишком сложно приблизить по соответсвию частот биграмм.
# </i></font>

# %% [markdown]
# ## 3️⃣ Частотный подход на основе биграмм
# Но и это ещё не всё: биграммы скорее всего тоже далеко не всегда работают. Основная часть задания — в том, как можно их улучшить:
# * предложите метод обучения перестановки символов в этом задании, основанный на MCMC-сэмплировании, но по-прежнему работающий на основе статистики биграмм;
# * реализуйте и протестируйте его, убедитесь, что результаты улучшились.

# %% [markdown]
# <font color='Navy'><i>
# ✏️ - Итак, у нас в распоряжении есть словарь частот, которую мы получили при тренировке на "Войне и Мир".
#     - Мы можем рассмотреть этот словарь биграмм $s_i$, $s_{i+1}$ частот как вероятности $p(s_{i+1} \mid s_i)$ (для строгих вероятностей надо отнормировать на сумму частот всех биграм, но это не обязательно).
#     - Тогда для данной строки $s$ можно вычислить её вероятность: $\mathbb{P_1}(s) = \displaystyle\prod_i^{len(s)}{p(s_{i+1} \mid s_i)} \sim \displaystyle\prod_i^{len(s)} frequency(s_i\,s_{i+1})$.
#     - Наша цель - это найти соответсвие между шифрованным (перестановочным) алфавитом и исходным алфавитом.
#     - В качестве начальной инициализции этого соответсвия (перестановки) будем использовать подход из первого пункта (Шерлока Холмса).
#     - Далее мы будем пытаться менять местами две позиции в этом соответсвии (перестановки) и считать новую вероятность $\mathbb{P_2}(s)$.
#     - Для принятия решения, стоит ли фиксировать новое соответсвие или оставаться при старом будем использовать подход алгоритма Метрополиса—Гастингса.
#     - Естественно, что можно перейти от произведений к суммам с помощью логарифмирования.
# </i></font>

# %%
def get_dict_translation(text: str, frequencies_dict: dict) -> str:
    """Получение словаря-соответсвия алфавитов для дешифровки на основе метода Шерлока Холмса."""
    
    sorted_frequencies_corpus = sorted(list(frequencies_dict.items()), key=lambda x: x[1], reverse=True)
    frequencies_alphabet1 = "".join([x[0] for x in sorted_frequencies_corpus])
    
    frequencies_dict2 = dict(Counter(text))
    sorted_frequencies_corpus2 = sorted(list(frequencies_dict2.items()), key=lambda x: x[1], reverse=True)
    frequencies_alphabet2 = "".join([x[0] for x in sorted_frequencies_corpus2])

    #     dict_translation = str.maketrans(frequencies_alphabet2, frequencies_alphabet1)
    dict_translation = dict(zip(frequencies_alphabet2, frequencies_alphabet1))

    return dict_translation

# %%
def get_new_dict_translation(dict_translation: dict) -> dict:
    """Возвращаем словарь соответсвий алфавитов, в котором случайно заменили две позиции."""
    new_dict = copy.copy(dict_translation)
    symbol1, symbol2 = np.random.choice(list(new_dict.keys()), size=2, replace=False)
    new_dict[symbol1], new_dict[symbol2] = new_dict[symbol2], new_dict[symbol1]
    
    return new_dict
    
def get_log_likelihood(text: str, dict_translation: dict, frequencies_bigram_dict: dict) -> float:
    """Возвращает вероятность строки на основе частот биграмм."""
    decode_text = translate_text(text, dict_translation) # text.translate(dict_translation)
    log_likelihood = 0
    for i in range(len(decode_text) - 2):
        log_likelihood += np.log(frequencies_bigram_dict[decode_text[i:i+2]])
    return log_likelihood


def metropolis_hastings_log_accept(l: float, l_new: float) -> bool:
    """Принимаем ли изменение в соответсвии на основе нового логарифма правдоподобия текста."""
    if l_new > l:
        return True
    else:
        return (np.random.rand() < (np.exp(l_new-l)))
    
def translate_text(text: str, dict_translation: dict) -> str:
    """Дешифровывает тест на основе словаря-соответствия алфавитов."""
    return "".join([dict_translation[x] for x in text])

# %%
def mcmc_decode_text(text: str, iterations: int, frequencies_dict: dict, frequencies_bigram_dict: dict) -> str:
    """Метод обучения соответсвия между алфавитами, основанный на MCMC-сэмплировании."""
    # Начальная инициализции соответсвия (перестановки) - подход из первого пункта (Шерлока Холмса).
    curr_dict_translation = get_dict_translation(text, frequencies_dict)
    curr_l = get_log_likelihood(text, curr_dict_translation, frequencies_bigram_dict)
    for i in range(iterations):
        new_dict_translation = get_new_dict_translation(curr_dict_translation)
        new_l = get_log_likelihood(text, new_dict_translation, frequencies_bigram_dict)
        if metropolis_hastings_log_accept(curr_l, new_l):
            curr_dict_translation, curr_l = new_dict_translation, new_l
    return translate_text(text, curr_dict_translation), curr_l  # text.translate(dict_translation)

# %%
# Словарь частот символов Войны и Мир. 
frequencies_dict = dict(Counter(corpus_rus))

# Словарь частот биграмм Войны и Мир.
frequencies_bigram_dict = get_frequencies_bigram_dict(corpus_rus)

# Тестовый отрывок.
EXAMPLE_TEXT_ANNA = anna_rus_text[32793:34793]
print("📖 Для тестирования взят отрывок из {} символов из Анны Карениной.\n".format(len(EXAMPLE_TEXT_ANNA)))

print("📍 Исходный текст:\n{}".format(EXAMPLE_TEXT_ANNA[:250]))
cipher_text = encode_text(EXAMPLE_TEXT_ANNA, dict_translation)
print("\n🔒 Зашифрованный текст:\n{}".format(cipher_text[:250]))
decode_cipher_text, _ = mcmc_decode_text(cipher_text, 4000, frequencies_dict, frequencies_bigram_dict)
print("\n🔐 Дешифрованный текст:\n{}".format(decode_cipher_text[:250]))

print("\n📈 Accuracy декодирования: {}".format(get_accuracy_decode(EXAMPLE_TEXT_ANNA, decode_cipher_text)))
# Out:
# 📖 Для тестирования взят отрывок из 2000 символов из Анны Карениной.
#
# 📍 Исходный текст:
# все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему все смешалось в доме облонских жена узнала что муж был в связи с бывшею в их доме француженкою гувернанткой и объявила мужу что не может жить с ним в одном доме
#
# 🔒 Зашифрованный текст:
# еыиьыэжыуъсетиьыичщсьпйлйосьд юшьфжьд юшжьмжоджзьфиыэжыуъсежзьыичщзьфиыэжыуъсежьпйьыейичюьеыиьычицжъйыщьеьдйчиьйкъйфымсльоифжьюнфжъжьэуйьчюоьктъьеьыезнсьыьктециаьеьсльдйчиья жфгюоифмйаьшюеи фжфумйрьсьйкбзесъжьчюоюьэуйьфиьчйоиуьосущьыьфсчьеьйдфйчьдйчи
#
# 🔐 Дешифрованный текст:
# все счастливые семьи похожи друг на друга каждая несчастливая семья несчастлива по своему все смешалось в доме облонских жена узнала что муж был в связи с бывшею в их доме француженкою гувернанткой и объявила мужу что не может жить с ним в одном доме
#
# 📈 Accuracy декодирования: 1.0

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Получили удивительный результат. Как мы помним метод из первого пункта на отрывке из $2000$ символов дал в результате $Accuracy = 0.52$. А сейчас мы наблюдаем, что метод на основе MCMC сэмплирования дал в результате $Accuracy = 1.0$, то есть нам удалось абсолютно правильно расшифровать текст за $4000$ итераций. Безусловно при меньшем числе итераций точность уменьшится, но даже при них результат сильно лучше, чем при базовом частотном варианте.
# </i></font>

# %% [markdown]
# ## 4️⃣ Расшифровываем неизвестные символы
# Расшифруйте сообщение:
# ←⇠⇒↟↹↷⇊↹↷↟↤↟↨←↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↟⇒↟↹⇷⇛⇞↨↟↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↨←⇌⇠↨↹⇙↹⇸↨⇛↙⇛↹⇠⇛⇛↲⇆←↝↟↞↹⇌⇛↨⇛⇯⇊↾↹⇒←↙⇌⇛↹⇷⇯⇛⇞↟↨⇴↨⇈↹ ⇠⇌⇛⇯←←↹↷⇠←↙⇛↹↷⇊↹↷⇠←↹⇠↤←⇒⇴⇒↟↹⇷⇯⇴↷↟⇒⇈↝⇛↹↟↹⇷ ⇛⇒⇙⇞↟↨←↹↳⇴⇌⇠↟↳⇴⇒⇈↝⇊↾↹↲⇴⇒⇒↹⇰⇴↹⇷⇛⇠⇒←↤↝←←↹⇞←↨↷←⇯↨⇛←↹⇰⇴↤⇴
# ↝↟←↹⇌⇙⇯⇠⇴↹↘⇛↨↞↹⇌⇛↝←⇞↝⇛↹↞↹↝↟⇞←↙⇛↹↝←↹⇛↲←⇆⇴⇏
#
# Или это (они одинаковые, второй вариант просто на случай проблем с юникодом):
#
# დჳჵჂႨშႼႨშჂხჂჲდႨსႹႭჾႣჵისႼჰႨჂჵჂႨႲႹႧჲჂႨსႹႭჾႣჵისႼჰႨჲდႩჳჲႨჇႨႠჲႹქႹႨჳႹႹჱჶდსჂႽႨႩႹჲႹႭႼჰႨჵდქႩႹႨႲႭႹႧჂჲႣჲიႨჳႩ
# ႹႭდდႨშჳდქႹႨშႼႨშჳდႨჳხდჵႣჵჂႨႲႭႣშჂჵისႹႨჂႨႲႹჵჇႧჂჲდႨჾႣႩჳჂჾႣჵისႼჰႨჱႣჵჵႨეႣႨႲႹჳჵდხსდდႨႧდჲშდႭჲႹდႨეႣხႣსჂდ
# ႨႩჇႭჳႣႨႾႹჲႽႨႩႹსდႧსႹႨႽႨსჂႧდქႹႨსდႨႹჱდჶႣნ

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Будем производить процесс сэмплирования несколько раз, чтобы в результате выбрать строку с наибольшим правдоподобием.
# </i></font>

# %%
# Словарь частот символов Войны и Мир. 
frequencies_dict = dict(Counter(corpus_rus))

# Словарь частот биграмм Войны и Мир.
frequencies_bigram_dict = get_frequencies_bigram_dict(corpus_rus)

MESSAGE = "←⇠⇒↟↹↷⇊↹↷↟↤↟↨←↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↟⇒↟↹⇷⇛⇞↨↟↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↨←⇌⇠↨↹⇙↹⇸↨⇛↙⇛↹⇠⇛⇛↲⇆←↝↟↞↹⇌⇛↨⇛⇯⇊↾↹⇒←↙⇌⇛↹⇷⇯⇛⇞↟↨⇴↨⇈↹⇠⇌⇛⇯←←↹↷⇠←↙⇛↹↷⇊↹↷⇠←↹⇠↤←⇒⇴⇒↟↹⇷⇯⇴↷↟⇒⇈↝⇛↹↟↹⇷⇛⇒⇙⇞↟↨←↹↳⇴⇌⇠↟↳⇴⇒⇈↝⇊↾↹↲⇴⇒⇒↹⇰⇴↹⇷⇛⇠⇒←↤↝←←↹⇞←↨↷←⇯↨⇛←↹⇰⇴↤⇴↝↟←↹⇌⇙⇯⇠⇴↹↘⇛↨↞↹⇌⇛↝←⇞↝⇛↹↞↹↝↟⇞←↙⇛↹↝←↹⇛↲←⇆⇴⇏"

print("🔒 Зашифрованное сообщение:\n{}".format(MESSAGE))
best_l = 0
best_decode_cipher_text = ""
for i in range(30):
    decode_cipher_text, curr_l = mcmc_decode_text(MESSAGE, 4000, frequencies_dict, frequencies_bigram_dict)
    if curr_l > best_l:
        best_decode_cipher_text, best_l = decode_cipher_text, curr_l
print("\n🔐 Расшифрованное сообщение:\n{}".format(best_decode_cipher_text))
# Out:
# 🔒 Зашифрованное сообщение:
# ←⇠⇒↟↹↷⇊↹↷↟↤↟↨←↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↟⇒↟↹⇷⇛⇞↨↟↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↨←⇌⇠↨↹⇙↹⇸↨⇛↙⇛↹⇠⇛⇛↲⇆←↝↟↞↹⇌⇛↨⇛⇯⇊↾↹⇒←↙⇌⇛↹⇷⇯⇛⇞↟↨⇴↨⇈↹⇠⇌⇛⇯←←↹↷⇠←↙⇛↹↷⇊↹↷⇠←↹⇠↤←⇒⇴⇒↟↹⇷⇯⇴↷↟⇒⇈↝⇛↹↟↹⇷⇛⇒⇙⇞↟↨←↹↳⇴⇌⇠↟↳⇴⇒⇈↝⇊↾↹↲⇴⇒⇒↹⇰⇴↹⇷⇛⇠⇒←↤↝←←↹⇞←↨↷←⇯↨⇛←↹⇰⇴↤⇴↝↟←↹⇌⇙⇯⇠⇴↹↘⇛↨↞↹⇌⇛↝←⇞↝⇛↹↞↹↝↟⇞←↙⇛↹↝←↹⇛↲←⇆⇴⇏
#
# 🔐 Расшифрованное сообщение:
# если вы вимите норжальный или подти норжальный текст у чтого сообшения который легко продитать скорее всего вы все смелали правильно и полудите жаксижальный балл за послемнее детвертое замание курса хотя конедно я нидего не обешаю

# %% [markdown]
# <font color='Navy'><i>
# ✏️ Итак, расшифрованное сообщение с лёгкостью читается: **"Если вы видите нормальный или почти нормальный текст у этого сообщения который легко прочитать скорее всего вы всё сделали правильно и получите максимальный балл за последнее четвертое задание курса хотя конечно я ничего не обещаю".**
# </i></font>
